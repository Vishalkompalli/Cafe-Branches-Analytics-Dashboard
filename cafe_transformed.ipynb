# %%
import pandas as pd

# %%
df1 = pd.read_csv('index_1.csv')

# %%
df1.head()
# Out:
#        date datetime cash_type                 card  money    coffee_name  \
# 0  3/1/2024  15:50.5      card  ANON-0000-0000-0001   38.7          Latte
# 1  3/1/2024  19:22.5      card  ANON-0000-0000-0002   38.7  Hot Chocolate
# 2  3/1/2024  20:18.1      card  ANON-0000-0000-0002   38.7  Hot Chocolate
# 3  3/1/2024  46:33.0      card  ANON-0000-0000-0003   28.9      Americano
# 4  3/1/2024  48:14.6      card  ANON-0000-0000-0004   38.7          Latte
#
#      stream    Stream
# 0  Stream A  Stream A
# 1  Stream A  Stream A
# 2  Stream A  Stream A
# 3  Stream A  Stream A
# 4  Stream A  Stream A

# %%
col_to_delete = ['stream', 'Stream']

# %%
df1 = df1.drop(columns=col_to_delete)

# %%
df1.head()
# Out:
#        date datetime cash_type                 card  money    coffee_name
# 0  3/1/2024  15:50.5      card  ANON-0000-0000-0001   38.7          Latte
# 1  3/1/2024  19:22.5      card  ANON-0000-0000-0002   38.7  Hot Chocolate
# 2  3/1/2024  20:18.1      card  ANON-0000-0000-0002   38.7  Hot Chocolate
# 3  3/1/2024  46:33.0      card  ANON-0000-0000-0003   28.9      Americano
# 4  3/1/2024  48:14.6      card  ANON-0000-0000-0004   38.7          Latte

# %%
df2 = pd.read_csv('index_2.csv')

# %%
df2.head()
# Out:
#        date        datetime cash_type  money            coffee_name
# 0  2/8/2025  2/8/2025 14:26      cash     15                    Tea
# 1  2/8/2025  2/8/2025 14:28      cash     15                    Tea
# 2  2/8/2025  2/8/2025 14:33      card     20               Espresso
# 3  2/8/2025  2/8/2025 15:51      card     30  Chocolate with coffee
# 4  2/8/2025  2/8/2025 16:35      cash     27    Chocolate with milk

# %%
df1['Stream'] = 'Stream A'
df2['Stream'] = 'Stream B'

# %%
merged_df = pd.concat([df1, df2], ignore_index=True)
merged_df.head()
# Out:
#        date datetime cash_type                 card  money    coffee_name  \
# 0  3/1/2024  15:50.5      card  ANON-0000-0000-0001   38.7          Latte
# 1  3/1/2024  19:22.5      card  ANON-0000-0000-0002   38.7  Hot Chocolate
# 2  3/1/2024  20:18.1      card  ANON-0000-0000-0002   38.7  Hot Chocolate
# 3  3/1/2024  46:33.0      card  ANON-0000-0000-0003   28.9      Americano
# 4  3/1/2024  48:14.6      card  ANON-0000-0000-0004   38.7          Latte
#
#      Stream
# 0  Stream A
# 1  Stream A
# 2  Stream A
# 3  Stream A
# 4  Stream A

# %%
merged_df.tail()
# Out:
#            date         datetime cash_type card  money  \
# 3893  3/23/2025  3/23/2025 14:55      cash  NaN   30.0
# 3894  3/23/2025  3/23/2025 15:15      card  NaN   25.0
# 3895  3/23/2025  3/23/2025 17:59      card  NaN   28.0
# 3896  3/23/2025  3/23/2025 18:01      card  NaN   28.0
# 3897  3/23/2025  3/23/2025 21:23      card  NaN   29.0
#
#                      coffee_name    Stream
# 3893                  Cappuccino  Stream B
# 3894               Irish whiskey  Stream B
# 3895             Super chocolate  Stream B
# 3896  Vanilla with Irish whiskey  Stream B
# 3897   Coffee with Irish whiskey  Stream B

# %%
merged_df['card'] = merged_df['card'].fillna("")

# %%
merged_df.tail()
# Out:
#            date         datetime cash_type card  money  \
# 3893  3/23/2025  3/23/2025 14:55      cash        30.0
# 3894  3/23/2025  3/23/2025 15:15      card        25.0
# 3895  3/23/2025  3/23/2025 17:59      card        28.0
# 3896  3/23/2025  3/23/2025 18:01      card        28.0
# 3897  3/23/2025  3/23/2025 21:23      card        29.0
#
#                      coffee_name    Stream
# 3893                  Cappuccino  Stream B
# 3894               Irish whiskey  Stream B
# 3895             Super chocolate  Stream B
# 3896  Vanilla with Irish whiskey  Stream B
# 3897   Coffee with Irish whiskey  Stream B

# %%
merged_df.duplicated().sum()
# Out:
# np.int64(2)

# %%
duplicated_rows = merged_df[merged_df.duplicated()]
print(duplicated_rows)
# Out:
#            date         datetime cash_type card  money          coffee_name  \
# 3747  2/26/2025   2/26/2025 9:41      cash        25.0  Americano with milk
# 3892  3/23/2025  3/23/2025 10:25      cash        25.0  Americano with milk
#
#         Stream
# 3747  Stream B
# 3892  Stream B
